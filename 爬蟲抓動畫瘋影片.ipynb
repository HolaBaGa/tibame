# %% [markdown]
# <a href="https://colab.research.google.com/github/HolaBaGa/tibame/blob/main/%E7%88%AC%E8%9F%B2%E6%8A%93%E5%8B%95%E7%95%AB%E7%98%8B%E5%BD%B1%E7%89%87.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 先從網頁原始碼找(下圖), 沒有才看F12 找隱藏網頁(圖3)
#
#
# 網址中?後面接參數, 通常只會出現1次
#
#
# 影片 通常在網頁中是分成一段一段, 注意副檔名 .ts 是Time slot時間段的意思, 影片在預覽頁面時會顯示"無法預覽", 回應頁面會類似亂碼的東西(下圖), 會亂碼是特別的格式(如mp4)
#
#
# .m3u8 是播放清單副檔名

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 爬蟲需搭配 FFMPEG 程式(圖1), 下載找到 bin>ffmpeg.exe 才能開始用
#
# 程式不可以有換行, 注意空格
#
# WIN: -headers "Origin: https://ani.gamer.com.tw" -i "" anime.mp4
#
# MAC: -headers 'Origin: https://ani.gamer.com.tw' -i '' anime.mp4
#
# =>WIN 跟 MAC 只差在-headers後面的參數是'跟", 小差別
#
# => 第一個參數-headers後面接要爬的Origin (圖4)
#
# => 第二個參數 -i 是要import後面的""值也就是(圖3)
#
# => 第三個參數  anime.mp4 檔名+附檔名

# %% [markdown]
# 圖1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 圖2 範例(PyCharm)
#
# 位置參數(放最後面, 一定會帶入的) 告訴她參數拿來幹嗎
#
# a. 短參數: -V -短參數名 值
#
# b. 長參數: --version --長參數名 值

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 圖3 成功找到影片清單網址, 影片會分成很多個片段, 如下圖有分到138個片段

# %% [markdown]
# ![螢幕擷取畫面 2026-05-16 144002.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 圖4 Origin的位置

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 圖5 程式碼介紹- 可以拖移EXE 或是資料夾進CMD 終端機
#
# 第一段為cd xxx 可執行的程式 參數 告知終端機我要的位置, 換為之後開頭就會直接顯示後面的參數檔案位置
#
# 第二段為解釋不同硬碟是不同世界, 要額外告知C碟或D碟
#
# 第三段為使用FFMPEG 下載影片的完整程式碼

# %% [markdown]
# ![image.png](data:image/png;base64,...)
