# %% [markdown]
# <a href="https://colab.research.google.com/github/HolaBaGa/tibame/blob/main/03MySQL_DML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 碰到危險的程式碼一定要再前面案 '#', 避免不小心執行


# delete from dept
where deptno = 88


# update dept
set
	dname = 'DEV-1',
    loc = 'Taipei',
    deptno = 88
where deptno = 99

# 子查詢使用在update敘述的set子句時
# 此子查詢必須是單欄單筆的結果

# %%
/* 03. 請修改資料表EMP的資料..
 * 	   將員工8888 的主管 改為 7839
 * 	   將員工9999 的主管 改為 8888
 */
# update emp
set mgr = 7839
where empno = 888;

# update emp
set mgr = 8888
where empno = 9999;

#----------------------------------------------
# 業界頃向分開寫, 不會用case 語法, 這裡單純只是練習
# update emp
set mgr =
	case empno
		when 8888 then 7839
		when 9999 then 8888
    end
where empno in (8888, 9999);
